# %%
# import sys
# !conda install --yes --prefix {sys.prefix} pymongo
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/anatolyilin/opt/anaconda3
#
#   added / updated specs:
#     - pymongo
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.11.0               |   py38hecd8cb5_0        14.4 MB
#     pymongo-3.12.0             |   py38h23ab428_0         1.3 MB
#     ------------------------------------------------------------
#                                            Total:        15.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   pymongo            pkgs/main/osx-64::pymongo-3.12.0-py38h23ab428_0
#
# The following packages will be UPDATED:
#
#   conda                               4.10.1-py38hecd8cb5_1 --> 4.11.0-py38hecd8cb5_0
#
#
#
# ...
# conda-4.11.0         | 14.4 MB   | ##################################### | 100%
# ...

# %%
from pymongo import MongoClient

# %%
connection_string = "mongodb://testuser:testpwd@127.0.0.1:27017/testDB"

# %%
conn = MongoClient(connection_string)

# %%
coll = conn['testDB']['cian_offers_images']

# %%
binary_image = coll.find_one({'_id' : 1185697905}).get('image')

# %%
from IPython.display import Image, display
display(Image(binary_image))
