# %%
import pickle

with open("../data/img/offers_images.pickle", 'rb') as r:
    data_modified = pickle.load(r)

# %%
test = data_modified[1210879568]

# %%
from IPython.display import Image, display
display(Image(test.content))

# %%
import pickle

with open("../data/raw/offers.pickle", 'rb') as r:
    data_modified = pickle.load(r)

# %%
data_modified.keys()
# Out:
# dict_keys([268897206, 267658875, 267735927, 267006835, 266887313, 251702875, 266004441, 267116478, 267123622, 266877117, 269021664, 266371609, 268953445, 266516591, 266394321, 260488716, 267312217, 248342165, 265457267, 266343975, 260789732, 268088297, 261363201, 268480124, 268338745, 268271912, 250879433, 265565287])

# %%
image_id = 1167074291

# %%
for offer in data_modified:
    photos = data_modified[offer]['photos']
    for photo in photos:
        if photo['id'] == image_id:
            print(data_modified[offer]['cianId'])
# Out:
# 265457267

# %%
pics = []
for offer in data_modified:
    photos = data_modified[offer]['photos']
    for photo in photos:
        pics.append(photo['id'] )

# %%
pics.index(1176285179)
# Out:
# 434

# %%
len(pics)
# Out:
# 632

# %%
pics.index(1168160213)/len(pics)*100.0
# Out:
# 99.5253164556962
