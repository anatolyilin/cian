# %%
import pymongo
import pandas as pd
import numpy as np
from pandas import DataFrame
from copy import deepcopy
from pymongo import MongoClient
from ipyleaflet import Map, basemaps, basemap_to_tiles, Marker, Popup
from ipywidgets import HTML, Layout

# %%
CONNECTION_STRING = "mongodb://testuser:testpwd@127.0.0.1:27017/testDB"

# %%
client = MongoClient(CONNECTION_STRING)

# %%
collection = client['testDB']["cian_offers"]

# %%
cursor = collection.find({})

# %%
items_df = DataFrame(cursor)

# %%
items_df[items_df['homeownerProofs'].notnull()]
# Out:
#             _id    userId permittedUseType  \
# 67    269029367  83350627             None
# 166   268684089  82890097             None
# 319   265608306  29495237             None
# 620   269183478  86272983             None
# 621   267379818  79759242             None
# 673   263850113  56927571             None
# 765   266809267  74217824             None
# 799   268710247  39850245             None
# 876   269212368  86313913             None
# 888   269245462  81438890             None
# 979   265022570  61854961             None
# 985   259641447  49939524             None
# 1005  268037376  84719192             None
# 1010  268336717  84906320             None
# 1011  268613206  85504243             None
# 1012  267869548  81044644             None
# 1015  259528043  75218715             None
# 1016  267591813  28132713             None
# 1018  269040465  86110405             None
# 1019  268843256  65429161             None
# 1022  255938655  68404573             None
# ...

# %%
items_df = items_df[items_df['homeownerProofs'].notnull()]

# %%
items_df
# Out:
#             _id    userId permittedUseType  \
# 67    269029367  83350627             None
# 166   268684089  82890097             None
# 319   265608306  29495237             None
# 620   269183478  86272983             None
# 621   267379818  79759242             None
# 673   263850113  56927571             None
# 765   266809267  74217824             None
# 799   268710247  39850245             None
# 876   269212368  86313913             None
# 888   269245462  81438890             None
# 979   265022570  61854961             None
# 985   259641447  49939524             None
# 1005  268037376  84719192             None
# 1010  268336717  84906320             None
# 1011  268613206  85504243             None
# 1012  267869548  81044644             None
# 1015  259528043  75218715             None
# 1016  267591813  28132713             None
# 1018  269040465  86110405             None
# 1019  268843256  65429161             None
# 1022  255938655  68404573             None
# ...

# %%
items_df['homeownerProofs'] = items_df['homeownerProofs'].map(lambda x: x if len(x)> 0 else pd.NA)

# %%
items_df[items_df['homeownerProofs'].notnull()]
# Out:
#             _id    userId permittedUseType  \
# 621   267379818  79759242             None
# 799   268710247  39850245             None
# 1005  268037376  84719192             None
# 1011  268613206  85504243             None
# 1334  265301297  49702759             None
#
#                                          fullUrl businessShoppingCenter  \
# 621   https://sochi.cian.ru/sale/flat/267379818/                   None
# 799   https://sochi.cian.ru/sale/flat/268710247/                   None
# 1005  https://sochi.cian.ru/sale/flat/268037376/                   None
# 1011  https://sochi.cian.ru/sale/flat/268613206/                   None
# 1334  https://sochi.cian.ru/sale/flat/265301297/                   None
#
#       addedTimestamp  isNew  \
# 621       1642844520  False
# 799       1642884975  False
# 1005      1642107504  False
# 1011      1642618417  False
# 1334      1635574348  False
#
#                                                     geo livingArea     status  \
# ...
